# %%
import pandas as pd

# %%
df = pd.read_csv('./datas/fine_food_reviews_1k.csv')

# %%
df.describe()
# Out:
#         Unnamed: 0          Time        Score
# count  1000.000000  1.000000e+03  1000.000000
# mean    499.500000  1.351172e+09     4.217000
# std     288.819436  4.286608e+04     1.288243
# min       0.000000  1.351123e+09     1.000000
# 25%     249.750000  1.351123e+09     4.000000
# 50%     499.500000  1.351210e+09     5.000000
# 75%     749.250000  1.351210e+09     5.000000
# max     999.000000  1.351210e+09     5.000000

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# Time          0
# ProductId     0
# UserId        0
# Score         0
# Summary       0
# Text          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'ProductId', 'UserId', 'Score', 'Summary',
#        'Text'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'ProductId', 'UserId', 'Score', 'Summary',
#        'Text'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0', 'Time', 'ProductId', 'UserId', 'Score', 'Summary', 'Text']

# %%
df.columns.tolist()[1:]
# Out:
# ['Time', 'ProductId', 'UserId', 'Score', 'Summary', 'Text']

# %%
df2 = df[df.columns.tolist()[1:]]

# %%
df2
# Out:
#            Time   ProductId          UserId  Score  \
# 0    1351123200  B003XPF9BO  A3R7JR3FMEBXQB      5
# 1    1351123200  B003JK537S  A3JBPC3WFUT5ZP      1
# 2    1351123200  B000JMBE7M   AQX1N6A51QOKG      4
# 3    1351123200  B004AHGBX4  A2UY46X0OSNVUQ      3
# 4    1351123200  B001BORBHO  A1AFOYZ9HSM2CZ      5
# ..          ...         ...             ...    ...
# 995  1351209600  B004OQLIHK   AKHQMSUORSA91      5
# 996  1351209600  B0006349W6  A21BT40VZCCYT4      5
# 997  1351209600  B00611F084   A6D4ND3C3BCYV      5
# 998  1351209600  B005QKH5HA  A3LR9HCV3D96I3      5
# 999  1351209600  B001EQ5GEO  A3VYU0VO6DYV6I      5
#
#                                                Summary  \
# 0    where does one  start...and stop... with a tre...
# 1                                    Arrived in pieces
# 2            It isn't blanc mange, but isn't bad . . .
# 3          These also have SALT and it's not sea salt.
# 4                               Happy with the product
# ...

# %%
df.columns.isna().sum()
# Out:
# np.int64(0)

# %%
df.index.isna().sum()
# Out:
# np.int64(0)
