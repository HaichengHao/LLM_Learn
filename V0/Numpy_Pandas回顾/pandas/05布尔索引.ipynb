# %%
import pandas as  pd

# %%
s1 = pd.Series([1,2,3,4,6,-1,9,-6])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    6
# 5   -1
# 6    9
# 7   -6
# dtype: int64

# %%
isgt5 =s1>=5

# %%
isgt5
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
s1[isgt5]
# Out:
# 4    6
# 6    9
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.bar(s1.index,s1.values)
plt.show()

# %%
s2=pd.Series({'a':1,'b':2,'c':3,'d':4},dtype=int)
s2
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
