# %%
import pandas as pd

# %%
s = pd.Series({'a':-1.2,'b':2.7,'c':3.5,'d':4.8})
bools=s>s.mean()
bools
# Out:
# a    False
# b     True
# c     True
# d     True
# dtype: bool

# %%
s[bools]
# Out:
# b    2.7
# c    3.5
# d    4.8
# dtype: float64

# %%
 s
# Out:
# a   -1.2
# b    2.7
# c    3.5
# d    4.8
# dtype: float64

# %%
s+10
# Out:
# a     8.8
# b    12.7
# c    13.5
# d    14.8
# dtype: float64

# %%
s*2
# Out:
# a   -2.4
# b    5.4
# c    7.0
# d    9.6
# dtype: float64
