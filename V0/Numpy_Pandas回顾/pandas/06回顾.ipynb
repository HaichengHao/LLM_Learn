# %%
import numpy as np
import pandas as pd

# %%
arr1 = np.random.randint(1,5,(3,4),dtype=int)

# %%
arr1
# Out:
# array([[3, 2, 3, 4],
#        [4, 3, 3, 1],
#        [1, 1, 4, 4]], dtype=int32)

# %%
arr1[:2,-3:]
# Out:
# array([[2, 3, 4],
#        [3, 3, 1]], dtype=int32)

# %%
s1 = pd.Series([10,20,30,40],index=['a','b','c','d'])

# %%
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s1.at['c']
# Out:
# np.int64(30)

# %%
s1.loc['c']
# Out:
# np.int64(30)
