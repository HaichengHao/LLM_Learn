# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('./datas/sleep.csv')

# %%
df.head()
# Out:
#    person_id  gender  age     occupation  sleep_duration  sleep_quality  \
# 0          1    Male   29   Manual Labor             7.4            7.0
# 1          2  Female   43        Retired             4.2            4.9
# 2          3    Male   44        Retired             6.1            6.0
# 3          4    Male   29  Office Worker             8.3           10.0
# 4          5    Male   67        Retired             9.1            9.5
#
#    physical_activity_level  stress_level bmi_category blood_pressure  \
# 0                       41             7        Obese         124/70
# 1                       41             5        Obese         131/86
# 2                      107             4  Underweight         122/70
# 3                       20            10        Obese         124/72
# 4                       19             4   Overweight         133/78
#
#    heart_rate  daily_steps sleep_disorder
# 0          91         8539            NaN
# ...

# %%
s1 = pd.Series([3,1,2,4]) #tips:pd.Series()可以将列表转换为Series对象

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1
# Out:
# 0    3
# 1    1
# 2    2
# 3    4
# dtype: int64

# %%
s2 = pd.Series(data=[1,2,3,4],index=['a','b','c','d'])

s2
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s3 = pd.Series([1,2,3,4],index=['a','b','c','d'],name="列标")
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: 列标, dtype: int64

# %%
s4 = pd.Series({"a":1,"b":2,"c":3,"d":4})
s4
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s5 =pd.Series({"a":1,"b":2,"c":3,"d":4},name="列标😮")

# %%
s5
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: 列标😮, dtype: int64

# %%
obj1={
    "data":{"a":1,"b":2,"c":3,"d":4},
    "name":"列标头名称"
}

s6 = pd.Series(**obj1)
s6
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: 列标头名称, dtype: int64
