# %%
import numpy as np

# %%
np.abs(-5)
# Out:
# np.int64(5)

# %%
arr1 = np.array([[1,-3,2,4,3.5],[2,-9,6,3.3,8],[9,0,-8,9.2,4]])
arr1
# Out:
# array([[ 1. , -3. ,  2. ,  4. ,  3.5],
#        [ 2. , -9. ,  6. ,  3.3,  8. ],
#        [ 9. ,  0. , -8. ,  9.2,  4. ]])

# %%
absarr1 = np.abs(arr1)
absarr1
# Out:
# array([[1. , 3. , 2. , 4. , 3.5],
#        [2. , 9. , 6. , 3.3, 8. ],
#        [9. , 0. , 8. , 9.2, 4. ]])

# %%
cellarr = np.ceil(arr1)
cellarr
# Out:
# array([[ 1., -3.,  2.,  4.,  4.],
#        [ 2., -9.,  6.,  4.,  8.],
#        [ 9.,  0., -8., 10.,  4.]])

# %%
floorarr = np.floor(arr1) #tips:向下取整
floorarr
# Out:
# array([[ 1., -3.,  2.,  4.,  3.],
#        [ 2., -9.,  6.,  3.,  8.],
#        [ 9.,  0., -8.,  9.,  4.]])

# %%
rintarr = np.rint(arr1) #tips：四舍六入五成双
rintarr
# Out:
# array([[ 1., -3.,  2.,  4.,  4.],
#        [ 2., -9.,  6.,  3.,  8.],
#        [ 9.,  0., -8.,  9.,  4.]])

# %%
type(np.nan)
# Out:
# float

# %%
arr3  = np.array([[1,2,3],[4,5,6]])

# %%
np.multiply(arr3,5)#tips:如果第二个参数传入的是数字的花那就是二维数组中的每个元素*数字
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30]])

# %%
arr4=np.array([[2,2,2],[3,3,3]])

np.multiply(arr3,arr4) #tips:数组和数组间的元素相乘
# Out:
# array([[ 2,  4,  6],
#        [12, 15, 18]])

# %%
np.where(arr3>4,11,22)  #tips:三元运算
# Out:
# array([[22, 22, 22],
#        [22, 11, 11]])

# %%
np.mean(arr3)
# Out:
# np.float64(3.5)

# %%
arr3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.max(arr3)
# Out:
# np.int64(6)

# %%
np.max(arr3,axis=0) #tips:统计每一列的最大值
# Out:
# array([4, 5, 6])

# %%
np.max(arr3,axis=1) #tips:统计每一行的最大值
# Out:
# array([3, 6])

# %%
np.std(arr3) #tips:统计标准差
# Out:
# np.float64(1.707825127659933)

# %%
np.var(arr3) #tips:统计方差
# Out:
# np.float64(2.9166666666666665)

# %%
arr3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.argmin(arr3,axis=0) #tips:按列找最小的索引下标
# Out:
# array([0, 0, 0])

# %%
np.argmin(arr3,axis=1) #tips:按行找最小值的索引下标
# Out:
# array([0, 0])

# %%
np.argmax(arr3,axis=0)
# Out:
# array([1, 1, 1])

# %%
np.argmax(arr3,axis=1)
# Out:
# array([2, 2])

# %%
np.cumsum(arr3,axis=0) #tips:返回一个数组,每个元素都是之前所有元素的累加和
# Out:
# array([[1, 2, 3],
#        [5, 7, 9]])

# %%
np.cumsum(arr3,axis=1)
# Out:
# array([[ 1,  3,  6],
#        [ 4,  9, 15]])
