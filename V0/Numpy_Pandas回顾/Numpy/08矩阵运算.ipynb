# %%
import numpy as np

# %% [markdown]
# 之前都是ndarry对位计算，还不算是矩阵运算

# %%
m1 = np.matrix([[1,2,3],[4,5,6]])
m2 = np.matrix([[6,5],[4,3],[2,1]])

# %%
mat1
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6]])

# %%
mat2
# Out:
# matrix([[ 7,  8,  9],
#         [10, 11, 12],
#         [13, 14, 15]])

# %%
np.dot(mat1,mat2)
# Out:
# matrix([[ 66,  72,  78],
#         [156, 171, 186]])
