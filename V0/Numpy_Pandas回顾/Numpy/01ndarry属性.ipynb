# %%
import numpy as np

# %%
a=[[1,2,3],[4,5,6]]
a
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
type(a)
# Out:
# list

# %%
arr = np.array([[1,2,3],[4,5,6]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
print(arr.ndim)
print(arr.shape)
print(arr.size) #数组元素个数
print(arr.dtype) #数组中元素的数据类型
print(arr.itemsize)
# Out:
# 2
# (2, 3)
# 6
# int64
# 8
