# %%
from pprint import pprint
from pymilvus import MilvusClient,DataType

#TIPS：实例化向量数据库
client = MilvusClient(
    uri='./demo_milvus.db'
)

# %%
def build_schema():


#TIPS 创建schema
client.create_collection(
    collection_name='test_collection',
    dimension=1024,  #bge-large-zh要求的维度是1024,这个要根据自己使用的模型来调整
    primary_field_name='id',#tips:首个字段的名称且其为主键
)
