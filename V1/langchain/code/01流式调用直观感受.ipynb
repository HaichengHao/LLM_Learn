# %%
import time

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

from openai import timeout

# %%
load_dotenv()

openai_api_key =os.getenv('api_key')
openai_base_url =os.getenv('base_url')

# %%
openaillm=ChatOpenAI(
    model='gpt-4o-mini',
    api_key=openai_api_key,
    base_url=openai_base_url,
    temperature=1.0
)


chat_prompt_template = ChatPromptTemplate(
    [
        ('system','你是一个动物语言学家'),
        # ('user','{user_input}')
    ]
)


parser = StrOutputParser()

# %%
chain = chat_prompt_template | openaillm | parser

# %%
import time
res = chain.stream(
"你好,你是谁?"
)
#important:流式返回的是生成器可迭代对象,所以可以用遍历的方式取出,但是注意生成器只能迭代一次
for r in res:
    # print(r)  #tips:打印输出的是一个个分散的,所以需要拼装
    print(r,end='',flush=True
          )
    time.sleep(0.25)
# Out:
# 你好！我是一个动物语言学家，专注于研究动物之间的交流与语言。我可以帮助你解答有关动物行为、交流方式或其他相关问题。有什么我可以帮你的吗？
